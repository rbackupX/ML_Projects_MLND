# %%
import pandas as pd

# %%
Metro_Rails = pd.read_excel("WorldMetro.xlsx")

# %%
Metro_Rails.head()
# Out:
#    #  Unnamed: 1  City   >       <  City aka   >.1             <.1  Country  \
# 0  1    Shanghai   NaN NaN     NaN       NaN   NaN           China      NaN
# 1  2     Beijing   NaN NaN  Peking       NaN   NaN           China      NaN
# 2  3      London   NaN NaN     NaN       NaN   NaN  United Kingdom      NaN
# 3  4   Guangzhou   NaN NaN  Canton       NaN   NaN           China      NaN
# 4  5    New York   NaN NaN     NaN       NaN   NaN             USA      NaN
#
#     >.2     ...      >.29                                               <.29  \
# 0   NaN     ...       NaN                                                yes
# 1   NaN     ...       NaN                                                yes
# 2   NaN     ...       NaN  Circle, District, Hammersmith & City and Metro...
# 3   NaN     ...       NaN                                                yes
# 4   NaN     ...       NaN                                                yes
#
# ...
