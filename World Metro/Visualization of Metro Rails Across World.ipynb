# %%
import pandas as pd

# %%
Metro_Rails = pd.read_excel("WorldMetro.xlsx")

# %%
Metro_Rails.head()
# Out:
#    #        City City aka         Country Continent       System  \
# 0  1    Shanghai      NaN           China      Asia        Metro
# 1  2     Beijing   Peking           China      Asia       Subway
# 2  3      London      NaN  United Kingdom    Europe  Underground
# 3  4   Guangzhou   Canton           China      Asia        Metro
# 4  5    New York      NaN             USA   America       Subway
#
#                Opening  Network length  Stations  Stations*  \
# 0  1995-04-10 00:00:00        632.1 km       394        284
# 1  1969-10-01 00:00:00        572.0 km       344        287
# 2          10 Jan 1863        402.0 km       270        270
# 3  1999-06-28 00:00:00        386.0 km       229        205
# 4  1904-10-27 00:00:00        380.2 km       473        426
#
#                          ...                          Gauge   Power supply  \
# 0                        ...                           1435  overhead wire
# ...
